# %% [markdown]
# <a href="https://colab.research.google.com/github/DushyantKhinchi/Paralyzed-Veterans-of-America-PVA-/blob/master/PVA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "drive/My Drive/PVA-Paralyzed Veterans of America/feature_selector.py"
# Out:
# 'drive/My Drive/PVA-Paralyzed Veterans of America/feature_selector.py'

# %%
import os
os.chdir('/content/drive/My Drive/PVA-Paralyzed Veterans of America/')

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/PVA-Paralyzed Veterans of America'

# %%
# Now we can import the library and use the function.
from feature_selector import FeatureSelector

# %%
import pandas as pd
import numpy as np

# %%
kdd98data = pd.read_csv('cup98LRN.csv', sep=',')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
kdd98data.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# %%
# Removing obvious variables
kdd98data.groupby('TARGET_B').count()
# Out:
#           ODATEDW  OSOURCE  TCODE  ...  MDMAUD_A  CLUSTER2  GEOCODE2
# TARGET_B                           ...
# 0           90569    89713  90569  ...     90569     90443     90263
# 1            4843     4771   4843  ...      4843      4837      4830
#
# [2 rows x 480 columns]

# %%
kdd98data.groupby('TCODE')['TARGET_B','TARGET_D'].mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#        TARGET_B   TARGET_D
# TCODE
# 0      0.053792   0.839149
# 1      0.046475   0.786871
# 2      0.049747   0.699812
# 3      0.044311   0.627545
# 4      0.054496   1.092643
# 6      0.000000   0.000000
# 7      0.000000   0.000000
# 9      0.500000   9.000000
# 12     0.000000   0.000000
# 13     0.044444   0.666667
# 14     0.090909   1.363636
# 17     0.000000   0.000000
# 18     0.058824   5.882353
# 21     0.000000   0.000000
# 22     0.000000   0.000000
# 23     0.000000   0.000000
# 24     0.000000   0.000000
# 25     0.000000   0.000000
# 27     0.000000   0.000000
# 28     0.046258   0.724600
# 30     0.285714   3.571429
# 36     1.000000   3.000000
# 38     0.000000   0.000000
# 40     0.000000   0.000000
# ...

# %%
kdd98data.groupby('TCODE').count()
# Out:
#        ODATEDW  OSOURCE  STATE    ZIP  ...  MDMAUD_F  MDMAUD_A  CLUSTER2  GEOCODE2
# TCODE                                  ...
# 0        40917    40556  40917  40917  ...     40917     40917     40863     40783
# 1        25691    25422  25691  25691  ...     25691     25691     25653     25595
# 2        17006    16850  17006  17006  ...     17006     17006     16980     16962
# 3          835      826    835    835  ...       835       835       834       833
# 4          367      364    367    367  ...       367       367       365       363
# 6            5        5      5      5  ...         5         5         5         4
# 7            1        1      1      1  ...         1         1         1         1
# 9            2        2      2      2  ...         2         2         2         2
# 12           1        1      1      1  ...         1         1         1         1
# 13          45       44     45     45  ...        45        45        45        45
# ...

# %%
kdd98data.drop(['AGEFLAG', 'DOB', 'GEOCODE2', 'LIFESRC', 'MAILCODE', 'NOEXCH', 'ODATEDW', 'OSOURCE', 'SOLP3', 'STATE', 'ZIP', 'TCODE'], axis=1, inplace=True)

# %%
feat_to_rm= [c for c in kdd98data.columns if c[:5] == 'RAMNT' or c[:5] == 'RDATE' ]

# %%
kdd98data.drop(feat_to_rm, axis=1, inplace=True)

# %%
#Converting to date format
kdd98data['LASTDATE']=kdd98data['LASTDATE'].astype(str) + '01'
kdd98data['ADATE_2']=kdd98data['ADATE_2'].astype(str) + '01'
kdd98data['MAXADATE']=kdd98data['MAXADATE'].astype(str)+ '01'

kdd98data['LASTDATE']=pd.to_datetime(kdd98data['LASTDATE'],format='%y%m%d',errors='coerce')
kdd98data['ADATE_2']=pd.to_datetime(kdd98data['ADATE_2'],format='%y%m%d',errors='coerce')
kdd98data['MAXADATE']=pd.to_datetime(kdd98data['MAXADATE'], format='%y%m%d', errors='coerce')

# %%
#DERIVED Features

# calculate the time difference between LAST_DATE and ADATE_2
from datetime import timedelta

kdd98data['TOT_WEEKS']=round((abs(kdd98data['LASTDATE']-kdd98data['ADATE_2']).dt.days)/7,2)
kdd98data['TOT_WEEKS']


#similarly, you can calculate the last promotion to gift time gap -- MAXADATE, ADATE_2
kdd98data['TOT_MAX_WEEKS']=round((abs(kdd98data['MAXADATE']-kdd98data['ADATE_2']).dt.days)/7,2)
kdd98data['TOT_MAX_WEEKS']


#average value of all responses, average value of response to all card promotions
kdd98data.loc[kdd98data.NUMPROM>0,'AVG_ALL_RESPONSE']=kdd98data['NGIFTALL']/kdd98data['NUMPROM']
kdd98data.loc[kdd98data.NUMPROM <= 0,'AVG_ALL_RESPONSE']=0


kdd98data.loc[kdd98data.CARDPROM>0,'AVG_CARD_RESPONSE']=kdd98data['CARDGIFT']/kdd98data['CARDPROM']
kdd98data.loc[kdd98data.CARDPROM <= 0,'AVG_CARD_RESPONSE']=0


#Similarly, you can create a new variable for last gift to max gift ratio

kdd98data.loc[kdd98data.MAXRAMNT>0,'LAST_MAX_GIFT']=kdd98data['LASTGIFT']/kdd98data['MAXRAMNT']
kdd98data.loc[kdd98data.MAXRAMNT <= 0,'LAST_MAX_GIFT']=0

#another new variable for ratio of max to min gift amount
kdd98data.loc[kdd98data.MAXRAMNT>0,'MIN_MAX_AMNT']=kdd98data['MINRAMNT']/kdd98data['MAXRAMNT']
kdd98data.loc[kdd98data.MAXRAMNT <= 0,'MIN_MAX_AMNT']=0



kdd98data[['AVG_ALL_RESPONSE', 'AVG_CARD_RESPONSE','LAST_MAX_GIFT','MIN_MAX_AMNT','TOT_WEEKS','TOT_MAX_WEEKS']]
# Out:
#        AVG_ALL_RESPONSE  AVG_CARD_RESPONSE  ...  TOT_WEEKS  TOT_MAX_WEEKS
# 0              0.418919           0.518519  ...      78.29          17.14
# 1              0.093750           0.083333  ...      78.29          17.14
# 2              0.428571           0.538462  ...      78.29          17.14
# 3              0.242424           0.259259  ...      78.29          17.14
# 4              0.327434           0.186047  ...      73.86          17.14
# ...                 ...                ...  ...        ...            ...
# 95407          0.071429           0.000000  ...      69.43          17.14
# 95408          0.100000           0.000000  ...      65.29          17.14
# 95409          0.212121           0.285714  ...      34.71          17.14
# 95410          0.322835           0.500000  ...      21.57          17.14
# 95411          0.280576           0.343750  ...      26.00          17.14
#
# [95412 rows x 6 columns]

# %%
feat_to_rm= [c for c in kdd98data.columns if c[:6] == 'ADATE_' or c[:4] == 'RFA_' ]

def Diff(li1, li2): 
    return (list(set(li1) - set(li2))) 
RFA=['RFA_2R','RFA_2F','RFA_2A']
feat_to_rm=Diff(feat_to_rm,RFA)

# %%
kdd98data.drop(feat_to_rm,axis=1,inplace=True)

# %%
kdd98data.loc[kdd98data.HOMEOWNR == 'H', 'HOMEOWNR'] = 1
kdd98data.loc[kdd98data.HOMEOWNR != 1 , 'HOMEOWNR'] = 0

# %%
def mutate(feat):
  kdd98data.loc[kdd98data[feat]=='X', feat]= 1
  kdd98data.loc[kdd98data[feat] !=1, feat] = 0

# %%
kdd98data.drop(['CHILD03', 'CHILD07','CHILD12','CHILD18'], axis=1, inplace=True)

# %%
mutate('RECINHSE')
mutate('RECP3')
mutate('RECPGVG')
mutate('RECSWEEP')
mutate('MAJOR')
mutate('PEPSTRFL')
mutate('RECPGVG')

# %%
kdd98data['RECPGVG'].unique()
# Out:
# array([0, 1], dtype=object)

# %%
#Replacing NA values with 0 in these variables
interestVars=['VETERANS', 'BIBLE','CATLG', 'HOMEE', 'PETS', 'CDPLAY', 'STEREO','PCOWNERS', 'PHOTO', 'CRAFTS', 'FISHER', 'GARDENIN', 'BOATS', 'WALKER', 'KIDSTUFF', 'CARDS', 'PLATES']

for i in interestVars:
  kdd98data[i].fillna(0, inplace=True)

# %%
kdd98data['PLATES'].unique()
# Out:
# array([0, 'Y'], dtype=object)

# %%
#Replacing Y with 1
def Replace_y(var):
  kdd98data.loc[kdd98data[var]=='Y', var]=1

for i in interestVars:
  Replace_y(i)

# %%
#Replacing NaN with -1
#the variables like MBBOOKS, MBCRAFT, etc give the number of known times the donor has responded to other  types of mail order offers.' -- so maybe the missing values here should be set to -1 (to differentiate from 0)

interestVars=['MBCRAFT', 'MBGARDEN', 'MBBOOKS', 'MBCOLECT', 'MAGFAML', 'MAGFEM', 'MAGMALE', 'PUBGARDN', 'PUBCULIN', 'PUBHLTH', 'PUBDOITY', 'PUBNEWFN', 'PUBPHOTO', 'PUBOPP']

for i in interestVars:
  kdd98data[i].fillna(-1, inplace=True)

# %%
#Replace strings with 'missing'
interestVars=['CLUSTER', 'GENDER', 'CLUSTER2', 'DOMAIN',  'WEALTH1', 'WEALTH2']

for i in interestVars:
  kdd98data[i].fillna('missing', inplace=True)

# %%
#the DOMAIN variable has 2 characters, first one for Urbanicity and the secoond for Socio-economic status. We want to separate these out into two variables

kdd98data['DOMAINU'] = kdd98data['DOMAIN'].str.get(0)
kdd98data['DOMAINSES'] = kdd98data['DOMAIN'].str.get(1)

# %%
#Replacing i with '5' in DOMAINSES so that it can be converted to int 

kdd98data.loc[kdd98data.DOMAINSES=='i', 'DOMAINSES']='5'

# %%
# Converting DOMAINSES to integer type

kdd98data['DOMAINSES']=kdd98data['DOMAINSES'].astype(int)

# %%
kdd98data[['DOMAINU', 'DOMAINSES', 'DOMAIN']]
# Out:
#       DOMAINU  DOMAINSES DOMAIN
# 0           T          2     T2
# 1           S          1     S1
# 2           R          2     R2
# 3           R          2     R2
# 4           S          2     S2
# ...       ...        ...    ...
# 95407       C          2     C2
# 95408       C          1     C1
# 95409       C          3     C3
# 95410       C          1     C1
# 95411       C          1     C1
#
# [95412 rows x 3 columns]

# %%
#remove some of the original attributes used for deriving new attributes
kdd98data.drop(['LASTDATE','MAXADATE','HOMEOWNR','MDMAUD_R','AGE902','HHAS2','CONTROLN','HPHONE_D','NGIFTALL','DOMAIN','DOMAINU', 'WEALTH2','WEALTH1'], axis=1, inplace=True)

# %%
#Class distribution
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.countplot(x="TARGET_B", data=kdd98data)
# sns.barplot(x="TARGET_B",y="cnt",data=kdd98data)
plt.show()

# %%
TARGET_B=kdd98data['TARGET_B']
TARGET_D=kdd98data['TARGET_D']
kdd98data.drop(['TARGET_B','TARGET_D'], axis=1, inplace=True)

# %%
kdd98data.drop(['RECP3','RECPGVG','RECSWEEP','MDMAUD','CLUSTER','GENDER','MAJOR','PEPSTRFL','POP90C1','POP90C2','POP90C3','POP90C4','POP90C5','AGE903','AGE905','AGE906','AGE907','CHIL1','CHIL2','CHIL3','HHAGE2','HHAGE3','MARR1','MARR2','MARR3','MARR4','HHP1','HHP2','HV1','HV3','HV4','MSA','ADI','DMA','IC1','IC2','IC6','IC7','IC8','IC9','LFC1','LFC2','LFC3','LFC6','LFC7','LFC8','LFC9','LFC10','EC2','EC3','EC4','EC5','EC6','EC7','EC8','MINRAMNT','MINRDATE','MAXRAMNT','MAXRDATE','FISTDATE','TIMELAG','AVGGIFT','RFA_2R','RFA_2F','RFA_2F','RFA_2F','MDMAUD_F','MDMAUD_A','CLUSTER2'], axis=1, inplace=True)

# %%
#Feature Engineering

fs = FeatureSelector(data = kdd98data, labels = TARGET_B)

# %%
#missing values

fs.identify_missing(missing_threshold=0.6)
# Out:
# 5 features with greater than 0.60 missing values.

# %%
fs.missing_stats.head(n=10)
# Out:
#           missing_fraction
# PVASTATE          0.984719
# COLLECT1          0.945479
# SOLIH             0.935019
# NUMCHLD           0.870184
# GEOCODE           0.840230
# AGE               0.248030
# INCOME            0.223096
# DATASRCE          0.223033
# NEXTDATE          0.104526
# OCC13             0.000000

# %%
#To see the features identified for removal, we access the ops attribute of the FeatureSelector
missing_features=fs.ops['missing'] 
missing_features
# Out:
# ['PVASTATE', 'NUMCHLD', 'SOLIH', 'GEOCODE', 'COLLECT1']

# %%
fs.plot_missing()

# %%
#Collinearity
fs.identify_collinear(correlation_threshold=0.9)
# Out:
# 46 features with a correlation magnitude greater than 0.90.

# %%
fs.plot_collinear()

# %%
collinear_features = fs.ops['collinear']
collinear_features
# Out:
# ['PUBPHOTO',
#  'POP902',
#  'POP903',
#  'ETH13',
#  'AGE904',
#  'HHAGE1',
#  'HHN4',
#  'HHN6',
#  'DW2',
#  'DW5',
#  'DW6',
#  'HU2',
#  'HHD1',
#  'HHD3',
#  'HHD4',
#  'HHD5',
#  'HHD9',
#  'HHD11',
#  'ETHC4',
#  'ETHC5',
#  'HVP1',
#  'HVP2',
#  'HVP4',
#  'HVP6',
#  'RHP1',
#  'RHP2',
#  'RHP3',
#  'HUPA2',
#  'HUPA6',
#  'RP2',
#  'IC4',
#  'IC19',
#  'IC20',
#  'IC21',
#  'IC22',
#  'IC23',
#  'HHAS1',
#  'TPE4',
#  'EIC1',
#  'AFC2',
#  'AFC5',
#  'LSC2',
#  'HC8',
#  'HC18',
#  'NUMPROM',
#  'NEXTDATE']

# %%
fs.record_collinear.head()
# Out:
#   drop_feature corr_feature  corr_value
# 0     PUBPHOTO     MBGARDEN    0.945007
# 1     PUBPHOTO     MBCOLECT    0.931591
# 2     PUBPHOTO       MAGFEM    0.906932
# 3     PUBPHOTO      MAGMALE    0.941115
# 4       POP902       POP901    0.988491

# %%
#The previous two methods can be applied to any structured dataset and are deterministic — the results will be the same every time for a given threshold
#The next method is designed only for supervised machine learning problems where we have labels for training a model and is non-deterministic. 

#Zero importance features based on GBM
fs.identify_zero_importance(task = 'classification', 
                            eval_metric = 'auc', 
                            n_iterations = 10, 
                             early_stopping = True)
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [77]	valid_0's binary_logloss: 0.198519	valid_0's auc: 0.594173
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [101]	valid_0's binary_logloss: 0.1965	valid_0's auc: 0.623027
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [118]	valid_0's binary_logloss: 0.196279	valid_0's auc: 0.62493
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [42]	valid_0's binary_logloss: 0.196836	valid_0's auc: 0.611147
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [96]	valid_0's binary_logloss: 0.195843	valid_0's auc: 0.626371
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# ...

# %%
zero_importance_features = fs.ops['zero_importance']
zero_importance_features
# Out:
# ['SOLIH_03',
#  'PLATES_1',
#  'SOLIH_00',
#  'SOLIH_01',
#  'SOLIH_02',
#  'KIDSTUFF_1',
#  'FISHER_1',
#  'SOLIH_04',
#  'BOATS_1',
#  'SOLIH_06',
#  'TOT_MAX_WEEKS',
#  'PHOTO_1',
#  'CDPLAY_1',
#  'PUBPHOTO',
#  'HOMEE_1',
#  'PVASTATE_E']

# %%
fs.plot_feature_importances(threshold = 0.9, plot_n = 12)
# Out:
# 201 features required for 0.90 of cumulative importance

# %%
#least important features
fs.identify_low_importance(cumulative_importance = 0.9)
# Out:
# 200 features required for cumulative importance of 0.90 after one hot encoding.
# 136 features do not contribute to cumulative importance of 0.90.

# %%
fs.feature_importances.head(10)
# Out:
#              feature  importance  normalized_importance  cumulative_importance
# 0          TOT_WEEKS        68.4               0.031319               0.031319
# 1                AGE        65.2               0.029853               0.061172
# 2  AVG_CARD_RESPONSE        54.2               0.024817               0.085989
# 3           LASTGIFT        44.2               0.020238               0.106227
# 4   AVG_ALL_RESPONSE        36.7               0.016804               0.123031
# 5           NUMPRM12        33.6               0.015385               0.138416
# 6           NEXTDATE        28.5               0.013049               0.151465
# 7             INCOME        25.1               0.011493               0.162958
# 8             POP902        21.8               0.009982               0.172940
# 9       MIN_MAX_AMNT        19.3               0.008837               0.181777

# %%
# features with constant values throughout or zero variance
fs.identify_single_unique()
# Out:
# 1 features with a single unique value.

# %%
fs.plot_unique()

# %%
# Remove the features based on all methods (returns a df)
kdd98data_tidy = fs.remove(methods = 'all', keep_one_hot=True)
# Out:
# ['missing', 'collinear', 'zero_importance', 'low_importance', 'single_unique'] methods have been run
#
# Removed 170 features.

# %%
kdd98data_tidy.shape
# Out:
# (95412, 190)

# %%
kdd98data_tidy
# Out:
#        RFA_2A_D  RFA_2A_G  ... LAST_MAX_GIFT  MIN_MAX_AMNT
# 0             0         0  ...      0.833333      0.416667
# 1             0         1  ...      1.000000      0.400000
# 2             0         0  ...      0.312500      0.125000
# 3             0         0  ...      0.909091      0.181818
# 4             0         0  ...      1.000000      0.200000
# ...         ...       ...  ...           ...           ...
# 95407         0         1  ...      1.000000      1.000000
# 95408         0         0  ...      1.000000      1.000000
# 95409         0         0  ...      1.000000      0.300000
# 95410         0         0  ...      0.857143      0.238095
# 95411         0         1  ...      0.497512      0.049751
#
# [95412 rows x 190 columns]

# %%
#Columns with null values
null_columns = []
for column in kdd98data_tidy.columns:
    if kdd98data_tidy[column].isnull().any():
       null_columns.append(column)
       print('Percentage of null values in {0} is {1} %'.format(column, round(kdd98data_tidy[column].isnull().mean()*100,2)))
# Out:
# Percentage of null values in AGE is 24.8 %
# Percentage of null values in INCOME is 22.31 %
# Percentage of null values in DATASRCE is 22.3 %

# %%
kdd98data_tidy['AGE']=kdd98data_tidy['AGE'].fillna(kdd98data_tidy['AGE'].median())
kdd98data_tidy['INCOME']=kdd98data_tidy['INCOME'].fillna(kdd98data_tidy['INCOME'].median())
kdd98data_tidy['DATASRCE']=kdd98data_tidy['DATASRCE'].fillna('3')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(kdd98data_tidy['RFA_2A'].astype(str))
kdd98data_tidy['RFA_2A']=le.transform(kdd98data_tidy['RFA_2A'].astype(str))
# kdd98data_tidy['RFA_2A']=le.transform(kdd98data_tidy['RFA_2A'].astype(str))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(kdd98data_tidy, TARGET_B, test_size=0.3, random_state=42)

# %%
y_train.value_counts() #imbalanced classes
# Out:
# 0    63369
# 1     3419
# Name: TARGET_B, dtype: int64

# %%
from imblearn.over_sampling import SMOTE 
sm = SMOTE(random_state = 2) 
X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
pd.DataFrame(y_train_res).value_counts()
# Out:
# 1    63369
# 0    63369
# dtype: int64

# %%
X_train_res.shape
# Out:
# (126738, 50)

# %%
X_train_res = pd.DataFrame(X_train_res, columns = X_train.columns.to_list())

# %%
## Import the random forest Classifier.
from sklearn.ensemble import RandomForestClassifier 
rf = RandomForestClassifier(n_estimators=100) 
rf.fit(X_train_res, y_train_res)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rf.score(X_train_res, y_train_res)
# Out:
# 0.9999921097066389

# %%
rf.score(X_test, y_test)
# Out:
# 0.9502166014533259

# %%
import pandas as pd
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X_train_res.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)
                                    
feature_importances.reset_index(inplace=True)
feature_importances
# Out:
#                 index  importance
# 0              RFA_2A    0.110092
# 1               ANC10    0.048000
# 2                IC13    0.043002
# 3             MBCRAFT    0.041456
# 4            RFA_2A_G    0.040729
# 5            CARDGIFT    0.039447
# 6                ANC8    0.034709
# 7                ANC9    0.033799
# 8             PUBHLTH    0.033074
# 9       LAST_MAX_GIFT    0.032781
# 10               ANC1    0.032718
# 11           LASTGIFT    0.032297
# 12              ETH16    0.030182
# 13           DATASRCE    0.025458
# 14           CARDPM12    0.023560
# 15           RFA_2A_D    0.023204
# 16             INCOME    0.020873
# 17                DW3    0.018395
# 18               PEC1    0.016737
# 19                HIT    0.016041
# 20       MIN_MAX_AMNT    0.015035
# 21             POP901    0.014887
# 22               HC16    0.014870
# 23               HHD8    0.014024
# 24              EIC12    0.013731
# 25           GARDENIN    0.013329
# ...

# %%
feature_importances['importance'][:38].sum()
# Out:
# 0.9071046902192487

# %%
Top_38_features=feature_importances['index'][0:38]
X_train_res=X_train_res[Top_38_features]
X_test=X_test[Top_38_features]

# %%
#Parameters used by our current forest

rf = RandomForestClassifier()
from pprint import pprint
print('Parameters currently in use:\n')
pprint(rf.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
#Hyperparameter Tuning grid

from sklearn.model_selection import RandomizedSearchCV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 200, num = 5)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 50, num = 5)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
pprint(random_grid)
# Out:
# {'bootstrap': [True, False],
#  'max_depth': [10, 20, 30, 40, 50, None],
#  'max_features': ['auto', 'sqrt'],
#  'min_samples_leaf': [1, 2, 4],
#  'min_samples_split': [2, 5, 10],
#  'n_estimators': [100, 125, 150, 175, 200]}

# %%
from sklearn.model_selection import RandomizedSearchCV
# Using random grid to search for best hyperparameters
# base model
rf = RandomForestClassifier()
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 5, cv = 3, verbose=2, random_state=42, n_jobs = 1)
# Fit the random search model
rf_random.fit(X_train_res, y_train_res)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=40, bootstrap=False
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=40, bootstrap=False, total=  36.0s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=40, bootstrap=False
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   36.0s remaining:    0.0s
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=40, bootstrap=False, total=  37.9s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=40, bootstrap=False
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=40, bootstrap=False, total=  37.1s
# ...

# %%
#Best Parameters
rf_random.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 200}

# %%
#Optimized Random Forest
rf = RandomForestClassifier(n_estimators=200, bootstrap=False, max_depth=None, max_features='sqrt', min_samples_leaf=1, min_samples_split=5) 
rf.fit(X_train_res, y_train_res)
# Out:
# RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rf.score(X_train_res, y_train_res)
# Out:
# 1.0

# %%
rf.score(X_test,y_test)
# Out:
# 0.9502515371716043

# %%
rf.predict_proba(X_test)[0:10,]
# Out:
# array([[0.90833333, 0.09166667],
#        [0.97541667, 0.02458333],
#        [0.78833333, 0.21166667],
#        [0.94208333, 0.05791667],
#        [0.97875   , 0.02125   ],
#        [0.88875   , 0.11125   ],
#        [0.89583333, 0.10416667],
#        [0.93458333, 0.06541667],
#        [0.85208333, 0.14791667],
#        [0.95166667, 0.04833333]])

# %%
y_pred_test=rf.predict(X_test)
y_pred_train=rf.predict(X_train_res)

# %%
#Confusion matrix for Training data
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
cm=confusion_matrix(y_train_res,y_pred_train)

sns.heatmap(cm, square=True, annot=True, cbar=False, cmap='Wistia', linewidths=0.2, linecolor='k' )
plt.xlabel('predicted value')
plt.ylabel('true value');

# %%
#Confusion matrix for testing data with threshold=0.1

threshold = 0.1

predicted_proba = rf.predict_proba(X_test)
predicted = (predicted_proba[:,1] >= threshold).astype('int')


cm=confusion_matrix(y_test,predicted)

sns.heatmap(cm, square=True, annot=True, cbar=False, cmap='Wistia', linewidths=0.2, linecolor='k' )
plt.xlabel('predicted value')
plt.ylabel('true value');

# %%
#Model Profitability with solicitation cost of $0.68 and average donation amount = $13
Profit = 13*490 - 0.68*(6500+490)
Profit
# Out:
# 1616.7999999999993

# %%
#Confusion matrix for testing data with threshold=0.2

threshold = 0.2

predicted_proba = rf.predict_proba(X_test)
predicted = (predicted_proba[:,1] >= threshold).astype('int')


cm=confusion_matrix(y_test,predicted)

sns.heatmap(cm, square=True, annot=True, cbar=False, cmap='Wistia', linewidths=0.2, linecolor='k' )
plt.xlabel('predicted value')
plt.ylabel('true value');

# %%
#Model Profitability with solicitation cost of $0.68 and average donation amount = $13
Profit = 13*54 - 0.68*(54+500)
Profit
# Out:
# 325.28

# %%
threshold = 0.5

predicted_proba = rf.predict_proba(X_test)
predicted = (predicted_proba[:,1] >= threshold).astype('int')


cm=confusion_matrix(y_test,predicted)

sns.heatmap(cm, square=True, annot=True, cbar=False, cmap='Wistia', linewidths=0.2, linecolor='k' )
plt.xlabel('predicted value')
plt.ylabel('true value');

# %%
#ROC plot
import sklearn.metrics as metrics

# calculate the fpr and tpr for all thresholds of the classification
probs = rf.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# # Regression

# %% [markdown]
# ## Random Forest

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error
X_train, X_test, y_train, y_test = train_test_split(kdd98data_tidy, TARGET_D, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

rfregressor = RandomForestRegressor()

# %%
rfregressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
ypred = rfregressor.predict(X_test)
ypred
# Out:
# array([0.  , 0.33, 1.27, ..., 0.7 , 0.55, 0.85])

# %%
mse=mean_squared_error(y_test,ypred)
rmse=np.sqrt(mse)
rmse
# Out:
# 4.751356096728772

# %% [markdown]
# ## OLS

# %%
from sklearn import linear_model

# %%
linmod = linear_model.LinearRegression(fit_intercept=False)
linmod.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=False, n_jobs=None, normalize=False)

# %%
ypred=linmod.predict(X_test)

# %%
mse=mean_squared_error(y_test,ypred)
rmse = np.sqrt(mse)
rmse
# Out:
# 4.552226273940657

# %% [markdown]
# ## GBM

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbm= GradientBoostingRegressor()
gbm.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
ypred=gbm.predict(X_test)
mse=mean_squared_error(y_test,ypred)
rmse = np.sqrt(mse)
rmse
# Out:
# 4.580249467461589
